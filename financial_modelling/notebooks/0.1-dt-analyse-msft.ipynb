# %%
import json
import pandas as pd
import pathlib
import plotly.express as px

# %%
json_paths = ["../data/MSFT_20200210213749.json", "../data/AAPL_20200210222048.json"]
dfs = []
for jp in json_paths:
    with open(jp, "r") as f:
        raw_data = json.load(f)
        temp_df = (pd
                   .DataFrame(raw_data["chart"])
                   .assign(stock=raw_data["quote"]["symbol"])
                   )
    dfs.append(temp_df)
df = pd.concat(dfs).reset_index(drop=True)

# %%
df
# Out:
#             date  uClose   uOpen   uHigh    uLow   uVolume   close    open  \
# 0     2015-02-09   42.36   42.24   42.74   42.21  31381061   42.36   42.24
# 1     2015-02-10   42.60   42.74   42.77   42.18  29670676   42.60   42.74
# 2     2015-02-11   42.38   42.65   42.65   42.21  38262509   42.38   42.65
# 3     2015-02-12   43.09   42.66   43.09   42.51  33268831   43.09   42.66
# 4     2015-02-13   43.87   43.38   43.87   43.15  40264887   43.87   43.38
# ...          ...     ...     ...     ...     ...       ...     ...     ...
# 1508  2020-02-03  308.66  304.30  313.49  302.22  43496401  308.66  304.30
# 1509  2020-02-04  318.85  315.31  319.64  313.63  34154134  318.85  315.31
# 1510  2020-02-05  321.45  323.52  324.76  318.95  29706718  321.45  323.52
# 1511  2020-02-06  325.21  322.57  325.22  320.26  26356385  325.21  322.57
# 1512  2020-02-07  320.03  322.37  323.40  318.00  29421012  320.03  322.37
#
#         high     low    volume  change  changePercent       label  \
# 0      42.74   42.21  31381061    0.00         0.0000   Feb 9, 15
# 1      42.77   42.18  29670676    0.24         0.5666  Feb 10, 15
# 2      42.65   42.21  38262509   -0.22        -0.5164  Feb 11, 15
# 3      43.09   42.51  33268831    0.71         1.6753  Feb 12, 15
# 4      43.87   43.15  40264887    0.78         1.8102  Feb 13, 15
# ...      ...     ...       ...     ...            ...         ...
# 1508  313.49  302.22  43496401   -0.85        -0.2746   Feb 3, 20
# 1509  319.64  313.63  34154134   10.19         3.3014   Feb 4, 20
# 1510  324.76  318.95  29706718    2.60         0.8154   Feb 5, 20
# 1511  325.22  320.26  26356385    3.76         1.1697   Feb 6, 20
# 1512  323.40  318.00  29421012   -5.18        -1.5928   Feb 7, 20
#
#       changeOverTime stock
# 0           0.000000  MSFT
# 1           0.005666  MSFT
# 2           0.000472  MSFT
# 3           0.017233  MSFT
# 4           0.035647  MSFT
# ...              ...   ...
# 1508        0.811279  AAPL
# 1509        0.871076  AAPL
# 1510        0.886333  AAPL
# 1511        0.908397  AAPL
# 1512        0.878000  AAPL
#
# [1513 rows x 16 columns]

# %%
fig = px.line(df, x="date", y="close", color="stock")
fig.show()
